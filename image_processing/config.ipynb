# %%
import torch

# %% [markdown]
# from typing import Optional
#
# <li>__all__ = ['__version__', 'debug', 'cuda', 'git_version', 'hip']
# <li>__version__ = '2.3.1+cu121'
# <li>debug = False
# <li>cuda: Optional[str] = '12.1'
# <li>git_version = 'd44533f9d073df13895333e70b66f81c513c1889'
# <li>hip: Optional[str] = None

# %%
CUDA_VISIBLE_DEVICES=0 python demo/inference_on_a_image.py \
-c groundingdino/config/GroundingDINO_SwinT_OGC.py \
-p ./weights/groundingdino_swint_ogc.pth \
-i .asset/cat_dog.jpeg \
-o logs/test1 \
-t "There is a cat and a dog in the image ."

# %%
python /home/GroundingDINO0/main.py /home/AIdrawG/static/dectect_work/oriImage_Vjz7kOn.jpg book oriImage.jpg
